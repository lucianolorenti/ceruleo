# %%
from ceruleo.graphics.control_chart import EWMAChart
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sbn
sbn.set()

# %%
data = np.random.rand(500)
fig, ax = plt.subplots()
bb = EWMAChart.build(data, target=1., weight=0.1, k=1.5)

bb.plot(data, ax)
# Out:
# <Axes: >
